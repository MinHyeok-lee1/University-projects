# %% [markdown]
# <a href="https://colab.research.google.com/github/MinHyeok-lee1/AICamera/blob/master/REAL_FINAL_TEST_256.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 필요한 라이브러리 다운로드
# 버전이 바뀌었을때 발생할 수 있는 오류들을 경고해주는 메시지
import warnings
#warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
# System related and data input controls
import os
# Data manipulation and visualization
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 10
pd.options.display.max_columns = 20
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc

import seaborn as sns

# Modeling algorithms
# General
import statsmodels.api as sm
from scipy import stats
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

from datetime import datetime
from pylab import rcParams
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

import itertools
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
# !pip install pmdarima
from pmdarima.arima import auto_arima

# Model selection
from sklearn.model_selection import train_test_split

from sklearn.datasets import load_breast_cancer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, f1_score, roc_auc_score

from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Evaluation metrics
# for regression
from sklearn.metrics import mean_squared_log_error, mean_squared_error,  r2_score, mean_absolute_error
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)

# %%
# 1) Upload Data - Input Data
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv', parse_dates=['date'])
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv', parse_dates=['date'])

# %%
daily_sales = train.groupby('date', as_index=False)['sales'].sum()
store_daily_sales = train.groupby(['store', 'date'], as_index=False)['sales'].sum()
item_daily_sales = train.groupby(['item', 'date'], as_index=False)['sales'].sum()

# %%
plt.figure(figsize=(20,8))
plt.plot(daily_sales['date'],daily_sales['sales'])
plt.title('Daily sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize=(20,8))

for i in range(1,11) :
    temp = store_daily_sales[store_daily_sales.store==i]
    plt.plot(temp['date'],temp['sales'], label = 'Store %d' % i)

plt.legend()
plt.title('Store Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize=(20,8))

for i in range(1,51) :
    temp = item_daily_sales[item_daily_sales.item==i]
    plt.plot(temp['date'],temp['sales'], label = 'Item %d' %i)

# plt.legend()
plt.title('Item Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# string 형태의 date 필드를 datetime 형태로 변환
train['date'] =  pd.to_datetime(train['date'])
df = train.set_index('date')

# 빠르게 테스트 해 보기 위해 월별로 아이템 판매 예측을 해 보기로 함
salesbymonth = df.drop(['store', 'item'], axis=1)
salesbymonth = salesbymonth.resample('M').sum()
# salesbymonth.groupby('date')[['sales']]
#2013-2016 데이터를 train으로 2017 데이터를 test로 분리
split = "2017-01-01"
salesbymonth_train= salesbymonth.loc[:split]
salesbymonth_test= salesbymonth.loc[split:]
salesbymonth_test_final=salesbymonth_test.copy()

train = train.set_index('date')
train_set= train.loc[:split]
test_set= train.loc[split:]
test_set_final=test_set.copy()

# %%
# 일, 주, 월, 년도 별 그래프 표시
def timeseries (x_axis, y_axis, x_label):
    plt.figure(figsize = (10, 6))
    plt.plot(x_axis, y_axis, color ='black')
    plt.xlabel(x_label, {'fontsize': 12}) 
    plt.ylabel('MK Product Sales', {'fontsize': 12})

# Graph by day, week, month
# 일별 그래프
df['day'] = df.index.day
train_by_day = df.resample('D').sum()
timeseries(train_by_day.index, train_by_day['sales'], 
           'Time(day)')

# 주별 그래프
df['week'] = df.index.week
train_by_week= df.resample('W').sum()
timeseries(train_by_week.index, train_by_week['sales'], 
           'Time(week)')

# 월별 그래프
df['month'] = df.index.month
train_by_year = df.resample('M').sum()
timeseries(train_by_year.index, train_by_year['sales'], 
           'Time (month)')

# 년도별 그래프
df['year'] = df.index.year
train_by_year = df.resample('Y').sum()
timeseries(train_by_year.index, train_by_year['sales'], 
           'Time (Year)')

# %%
#방법 1. p,d,q의 조합을 만들어 하나하나 ARIMA 모델을 돌려봄
p = d = q = range(0, 2)

import itertools
pdqa = list(itertools.product(p, d, q))

seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

for param in pdqa:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(salesbymonth_train, order=param, seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)                                
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
            
#방법 2. auto_arima 함수로 자동 추출
from pmdarima import auto_arima
stepwise_model = auto_arima(salesbymonth_train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1412.2229228457459
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:5516633.458516287
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:887.6565547548751
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:590.2742084017133
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:853.4883695710716
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1078.790120110935
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:580.0775060965184
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:526.6134096757977
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1352.903523073248
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:5141891.975204614
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:839.3267866283813
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:541.8274398335935
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1050.1679331711603
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:4885684.224247755
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:588.7594055535517
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:540.4312566499182
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1196.0971642680395
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:94622.82225503924
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:763.3653535193848
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:488.238632996585
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:780.3980696212058
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:93678.63737628782
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:510.29124491877155
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:489.66415603719895
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1169.5083236759347
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:65629.5286811122
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:742.8675372454898
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:467.77716968852917
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:879.1061891314246
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:69055.3703291936
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:512.277816012122
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:468.36613977957614
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1222.9450063459788
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:94648.4420153248
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:785.9184325599133
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:511.1667183893134
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:879.4888727881087
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:93834.30679504937
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:513.31872722406
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:512.8016777753403
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1198.6333553858458
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:94539.69453819742
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:766.2785436187106
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:489.95359133220103
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:880.7885701907355
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:64863.235316877486
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:513.5190917075055
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:491.7784765350806
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1196.2612965737585
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:92680.31318658768
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:765.2133917854477
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:487.9652822667058
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:854.0628717312085
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:89035.90964034741
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:490.0999272680091
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:489.5928137406578
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1170.6662687593762
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:67852.72559247872
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:743.442190300153
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:468.6897835650361
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:856.1368328470222
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:64426.021158378484
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:493.15741154917004
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:469.35261854706005
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=775.474, Time=0.12 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=784.706, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=774.061, Time=0.08 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=773.779, Time=0.10 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=786.609, Time=0.03 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=775.686, Time=0.46 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=775.734, Time=0.21 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=774.156, Time=0.09 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=1.05 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=770.820, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=772.724, Time=0.13 sec
#  ARIMA(0,1,0)(0,1,2)[12]             : AIC=772.374, Time=0.20 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=767.799, Time=0.13 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=772.845, Time=0.19 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=inf, Time=0.82 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=775.833, Time=0.35 sec
#  ARIMA(0,1,0)(1,1,0)[12] intercept   : AIC=773.761, Time=0.18 sec
#
# Best model:  ARIMA(0,1,0)(1,1,0)[12]
# Total fit time: 4.269 seconds

# %%
# 2) ARIMA
# 그래프에 대한 관측치, 추세, 계절성, 잔차 표시
SARIMAMonth = sm.tsa.statespace.SARIMAX(
    salesbymonth,
     order=(0, 1, 0),
      seasonal_order=(1, 1, 0, 12),
      enforce_stationarity=False,
      enforce_invertibility=False
      )

SARIMA_results_month = SARIMAMonth.fit()
SARIMA_results_month.plot_diagnostics(figsize=(12, 10))
plt.show()


plt.rcParams['figure.figsize'] = (18, 8)
result = sm.tsa.seasonal_decompose(salesbymonth_train,model='additive')
fig = plt.figure()
fig = result.plot()

# %%
# 2017년 12개월 데이터로 예측
SARIMA_predict_month_1 = SARIMA_results_month.predict(start=48,end=60)

# 결과 비교를 위해 기존에 마련해둔 test데이터에 결과를 붙임
salesbymonth_test_final['SeasonalARIMA'] = SARIMA_predict_month_1

# test 데이터와 예측 결과치를 비교
salesbymonth_test_final[1:].plot()

# %%
# Xgboost
# store / item 별로 월별 판매를 합산
df = df.groupby(['store', 'item'])['sales'].resample('M').sum()
df = df.reset_index()
df = df.set_index('date')

df['month'] = df.index.month
df['year'] = df.index.year
df['dayofweek'] = df.index.dayofweek

#2013-2016 데이터를 train으로 2017 데이터를 test로 분리
split = "2017-01-01"
train_data= df.loc[:split]
test_data= df.loc[split:]

# y값은 판매량, 나머지 항목들로 x값을 구성
Xgboost_train_y = df.loc[:,'sales']
Xgboost_train_x = df.drop('sales', axis=1)
Xgboost_test_y = df.loc[:,'sales']
Xgboost_test_x = df.drop('sales', axis=1)

# 추후에 예측값과 비교하기 위해 test 데이터 복제본 저장
Xgboost_test_orig = test_data.loc[:, ['store', 'item', 'sales']]

XG_model_month = xgb.XGBRegressor(n_estimators=1000)
XG_model_month.fit(Xgboost_train_x, Xgboost_train_y, eval_set=[(Xgboost_test_x, Xgboost_test_y)], early_stopping_rounds=20,verbose=True)

# 주요하게 적용하는 변수를 판단
plot_importance(XG_model_month, height=0.9)
# Out:
# [07:10:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1642.44
# Will train until validation_0-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:1511.85
# [2]	validation_0-rmse:1397.02
# [3]	validation_0-rmse:1296.29
# [4]	validation_0-rmse:1208.12
# [5]	validation_0-rmse:1128.02
# [6]	validation_0-rmse:1060.59
# [7]	validation_0-rmse:1001.14
# [8]	validation_0-rmse:950.948
# [9]	validation_0-rmse:907.323
# [10]	validation_0-rmse:866.123
# [11]	validation_0-rmse:829.991
# [12]	validation_0-rmse:800.454
# [13]	validation_0-rmse:773.864
# [14]	validation_0-rmse:753.497
# [15]	validation_0-rmse:733.389
# [16]	validation_0-rmse:717.843
# [17]	validation_0-rmse:703.834
# [18]	validation_0-rmse:688.98
# [19]	validation_0-rmse:677.553
# [20]	validation_0-rmse:666.913
# [21]	validation_0-rmse:655.847
# [22]	validation_0-rmse:648.25
# [23]	validation_0-rmse:639.14
# [24]	validation_0-rmse:633.701
# [25]	validation_0-rmse:627.06
# [26]	validation_0-rmse:619.911
# [27]	validation_0-rmse:615.479
# [28]	validation_0-rmse:610.278
# [29]	validation_0-rmse:606.844
# [30]	validation_0-rmse:602.904
# [31]	validation_0-rmse:598.858
# [32]	validation_0-rmse:595.989
# [33]	validation_0-rmse:593.258
# [34]	validation_0-rmse:586.465
# [35]	validation_0-rmse:584.316
# [36]	validation_0-rmse:581.548
# [37]	validation_0-rmse:578.499
# [38]	validation_0-rmse:573.292
# [39]	validation_0-rmse:571.594
# [40]	validation_0-rmse:567.155
# [41]	validation_0-rmse:563.291
# [42]	validation_0-rmse:560.777
# [43]	validation_0-rmse:558.908
# [44]	validation_0-rmse:551.054
# [45]	validation_0-rmse:548.074
# [46]	validation_0-rmse:546.199
# [47]	validation_0-rmse:544.886
# [48]	validation_0-rmse:542.792
# [49]	validation_0-rmse:541.183
# [50]	validation_0-rmse:532.491
# [51]	validation_0-rmse:530.855
# [52]	validation_0-rmse:525.482
# [53]	validation_0-rmse:519.09
# [54]	validation_0-rmse:517.695
# [55]	validation_0-rmse:516.463
# [56]	validation_0-rmse:511.709
# [57]	validation_0-rmse:509.996
# [58]	validation_0-rmse:508.82
# [59]	validation_0-rmse:507.479
# [60]	validation_0-rmse:506.407
# [61]	validation_0-rmse:504.974
# [62]	validation_0-rmse:501.429
# [63]	validation_0-rmse:500.359
# [64]	validation_0-rmse:498.832
# [65]	validation_0-rmse:497.886
# [66]	validation_0-rmse:490.191
# [67]	validation_0-rmse:484.835
# [68]	validation_0-rmse:482.896
# [69]	validation_0-rmse:481.958
# [70]	validation_0-rmse:480.366
# [71]	validation_0-rmse:477.119
# [72]	validation_0-rmse:476.201
# [73]	validation_0-rmse:475.429
# [74]	validation_0-rmse:474.692
# [75]	validation_0-rmse:473.558
# [76]	validation_0-rmse:467.103
# [77]	validation_0-rmse:464.398
# [78]	validation_0-rmse:461.773
# [79]	validation_0-rmse:460.19
# [80]	validation_0-rmse:459.171
# [81]	validation_0-rmse:458.427
# [82]	validation_0-rmse:451.715
# [83]	validation_0-rmse:447.505
# [84]	validation_0-rmse:445.777
# [85]	validation_0-rmse:436.56
# [86]	validation_0-rmse:431.14
# [87]	validation_0-rmse:430.366
# [88]	validation_0-rmse:428.389
# [89]	validation_0-rmse:423.126
# [90]	validation_0-rmse:420.35
# [91]	validation_0-rmse:411.887
# [92]	validation_0-rmse:408.858
# [93]	validation_0-rmse:407.954
# [94]	validation_0-rmse:407.022
# [95]	validation_0-rmse:406.348
# [96]	validation_0-rmse:404.643
# [97]	validation_0-rmse:399.801
# [98]	validation_0-rmse:392.588
# [99]	validation_0-rmse:387.726
# [100]	validation_0-rmse:383.626
# [101]	validation_0-rmse:383.128
# [102]	validation_0-rmse:377.218
# [103]	validation_0-rmse:373.777
# [104]	validation_0-rmse:372.329
# [105]	validation_0-rmse:368.671
# [106]	validation_0-rmse:364.627
# [107]	validation_0-rmse:361.344
# [108]	validation_0-rmse:359.981
# [109]	validation_0-rmse:357.935
# [110]	validation_0-rmse:357.033
# [111]	validation_0-rmse:356.422
# [112]	validation_0-rmse:354.349
# [113]	validation_0-rmse:350.052
# [114]	validation_0-rmse:348.753
# [115]	validation_0-rmse:345.774
# [116]	validation_0-rmse:344.796
# [117]	validation_0-rmse:341.37
# [118]	validation_0-rmse:340.685
# [119]	validation_0-rmse:339.667
# [120]	validation_0-rmse:337.705
# [121]	validation_0-rmse:337.056
# [122]	validation_0-rmse:335.154
# [123]	validation_0-rmse:334.327
# [124]	validation_0-rmse:333.802
# [125]	validation_0-rmse:333.36
# [126]	validation_0-rmse:330.085
# [127]	validation_0-rmse:326.798
# [128]	validation_0-rmse:323.741
# [129]	validation_0-rmse:323.163
# [130]	validation_0-rmse:320.51
# [131]	validation_0-rmse:318.815
# [915]	validation_0-rmse:145.003
# [916]	validation_0-rmse:144.921
# [917]	validation_0-rmse:144.861
# [918]	validation_0-rmse:144.796
# [919]	validation_0-rmse:144.734
# [920]	validation_0-rmse:144.666
# [921]	validation_0-rmse:144.64
# [922]	validation_0-rmse:144.622
# [923]	validation_0-rmse:144.61
# [924]	validation_0-rmse:144.592
# [925]	validation_0-rmse:144.552
# [926]	validation_0-rmse:144.524
# [927]	validation_0-rmse:144.475
# [928]	validation_0-rmse:144.453
# [929]	validation_0-rmse:144.425
# [930]	validation_0-rmse:144.412
# [931]	validation_0-rmse:144.356
# [932]	validation_0-rmse:144.315
# [933]	validation_0-rmse:144.183
# [934]	validation_0-rmse:144.15
# [935]	validation_0-rmse:144.08
# [936]	validation_0-rmse:144.054
# [937]	validation_0-rmse:144.004
# [938]	validation_0-rmse:143.986
# [939]	validation_0-rmse:143.906
# [940]	validation_0-rmse:143.846
# [941]	validation_0-rmse:143.774
# [942]	validation_0-rmse:143.751
# [943]	validation_0-rmse:143.727
# [944]	validation_0-rmse:143.682
# [945]	validation_0-rmse:143.658
# [946]	validation_0-rmse:143.643
# [947]	validation_0-rmse:143.6
# [948]	validation_0-rmse:143.586
# [949]	validation_0-rmse:143.578
# [950]	validation_0-rmse:143.57
# [951]	validation_0-rmse:143.51
# [952]	validation_0-rmse:143.472
# [953]	validation_0-rmse:143.452
# [954]	validation_0-rmse:143.421
# [955]	validation_0-rmse:143.372
# [956]	validation_0-rmse:143.322
# [957]	validation_0-rmse:143.298
# [958]	validation_0-rmse:143.283
# [959]	validation_0-rmse:143.267
# [960]	validation_0-rmse:143.255
# [961]	validation_0-rmse:143.22
# [962]	validation_0-rmse:143.196
# [963]	validation_0-rmse:143.157
# [964]	validation_0-rmse:143.143
# [965]	validation_0-rmse:143.118
# [966]	validation_0-rmse:142.991
# [967]	validation_0-rmse:142.947
# [968]	validation_0-rmse:142.813
# [969]	validation_0-rmse:142.797
# [970]	validation_0-rmse:142.78
# [971]	validation_0-rmse:142.761
# [972]	validation_0-rmse:142.71
# [973]	validation_0-rmse:142.691
# [974]	validation_0-rmse:142.667
# [975]	validation_0-rmse:142.586
# [976]	validation_0-rmse:142.477
# [977]	validation_0-rmse:142.466
# [978]	validation_0-rmse:142.452
# [979]	validation_0-rmse:142.428
# [980]	validation_0-rmse:142.408
# [981]	validation_0-rmse:142.401
# [982]	validation_0-rmse:142.32
# [983]	validation_0-rmse:142.291
# [984]	validation_0-rmse:142.269
# [985]	validation_0-rmse:142.219
# [986]	validation_0-rmse:142.215
# [987]	validation_0-rmse:142.199
# [988]	validation_0-rmse:142.186
# [989]	validation_0-rmse:142.156
# [990]	validation_0-rmse:142.112
# [991]	validation_0-rmse:142.093
# [992]	validation_0-rmse:142.084
# [993]	validation_0-rmse:142.067
# [994]	validation_0-rmse:142.059
# [995]	validation_0-rmse:142.002
# [996]	validation_0-rmse:141.977
# [997]	validation_0-rmse:141.914
# [998]	validation_0-rmse:141.86
# [999]	validation_0-rmse:141.846

# %%
# plot_future(Xgboost, 'Xgboost', Xgboost_test_y)
result_xgboost=pd.concat([Xgboost_test_orig.reset_index(), pd.DataFrame(Xgboost, columns=['Xgboost'])], axis=1, ignore_index=False)
result_xgboost = result_xgboost.groupby(['date']).sum()
result_xgboost = result_xgboost.loc[:, ['sales', 'Xgboost']]
result_xgboost

result_xgboost.plot()

# %%
# train_data = salesbymonth_train.reset_index()
# test_data= salesbymonth_test.reset_index()

# 빠르게 테스트 해 보기 위해 월별로 아이템 판매 예측을 해 보기로 함
df2 = train.drop(['store', 'item'], axis=1)
df2 = df2.reset_index()
df2 = df2.groupby('date').sum()['sales']
df2 = df2.reset_index()

# 결측값 처리
# Check for missing values
print('Total num of missing values:') 
print(df2.sales.isna().sum())
print('')
# Locate the missing value
df_missing_date = df2.loc[df2.sales.isna() == True]
print('The date of missing value:')
print(df_missing_date.loc[:,['date']])
# Replcase missing value with interpolation
df2.sales.interpolate(inplace = True)
# Keep WC and drop Date
df2 = df2.drop('date', axis = 1)
# Out:
# Total num of missing values:
# 0
#
# The date of missing value:
# Empty DataFrame
# Columns: [date]
# Index: []

# %%
# Split train data and test data
train_size = int(len(df2)*0.8)

train_data = df2.iloc[:train_size]
test_data = df2.iloc[train_size:]

scaler = MinMaxScaler().fit(train_data)
train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# Create input train
def create_train (X, look_back = 1):
    Xs, ys = [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
 
    return np.array(Xs), np.array(ys)
LOOK_BACK = 30

X_train, y_train = create_train(train_scaled,LOOK_BACK)
X_test, y_test = create_train(test_scaled,LOOK_BACK)
# Print data shape
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)


# Create LSTM model
def create_lstm(units):
    # input shape에 전처리된 train_x의 형태를 넣는다
    # 20%로 Drop-out 했다
    model = keras.Sequential()
    model.add(keras.layers.LSTM(units = units,input_shape=(X_train.shape[1], X_train.shape[2])))
    # model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(keras.layers.Dense(units=units))
    # model.add(Dropout(0.2)) 
    model.add(Dense(1))
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

# Create BiLSTM model
def create_bilstm(units):
    model = Sequential()
    # Input layer
    model.add(Bidirectional(
              LSTM(units = units, return_sequences=True), 
              input_shape=(X_train.shape[1], X_train.shape[2])))
    # model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(Bidirectional(LSTM(units = units)))
    # model.add(Dropout(0.2))
    model.add(Dense(1))
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

# Create GRU model
def create_gru(units):
    model = Sequential()
    # Input layer
    model.add(GRU (units = units, return_sequences = True, 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

# Create BiGRU model
def create_bigru(units):
    model = Sequential()
    # Input layer
    model.add(Bidirectional(
        GRU (units = units, return_sequences = True), 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model


def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                               patience = 10)
    history = model.fit(X_train, y_train, epochs = 100,  
                        validation_split = 0.2,
                        batch_size = 16, shuffle = False, 
                        callbacks = [early_stop])
    return history


def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')


# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    return prediction

# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    prediction = scaler.inverse_transform(prediction)
    plt.figure(figsize=(18, 8))
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='Test data')
    plt.plot(np.arange(range_future), 
             np.array(prediction),label='Prediction')
    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('Counts')

model_lstm = create_lstm(256)
model_bilstm = create_bilstm(256)
model_gru = create_gru(256)
model_bigru = create_bilstm(256)

history_lstm = fit_model(model_lstm)
history_bilstm = fit_model(model_bilstm)
history_gru = fit_model(model_gru)
history_bigru = fit_model(model_bigru)

y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

plot_loss (history_lstm, 'LSTM')
plot_loss (history_bilstm, 'Bidirectional LSTM')
plot_loss (history_gru, 'GRU')
plot_loss (history_gru, 'Bidirectional GRU')
# Out:
# X_train.shape:  (1430, 30, 1)
# y_train.shape:  (1430, 1)
# X_test.shape:  (336, 30, 1)
# y_test.shape:  (336, 1)
# Epoch 1/100
# 72/72 [==============================] - 9s 101ms/step - loss: 0.0172 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0183 - accuracy: 0.0000e+00 - val_loss: 0.0895 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 72/72 [==============================] - 7s 90ms/step - loss: 0.0240 - accuracy: 0.0000e+00 - val_loss: 0.1039 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0260 - accuracy: 0.0000e+00 - val_loss: 0.0868 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 72/72 [==============================] - 7s 91ms/step - loss: 0.0241 - accuracy: 0.0000e+00 - val_loss: 0.0605 - val_accuracy: 0.0035
# Epoch 6/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0186 - accuracy: 0.0000e+00 - val_loss: 0.0265 - val_accuracy: 0.0035
# Epoch 7/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0131 - accuracy: 0.0000e+00 - val_loss: 0.0231 - val_accuracy: 0.0035
# Epoch 8/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0323 - val_accuracy: 0.0035
# Epoch 9/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0252 - val_accuracy: 0.0035
# Epoch 10/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0270 - val_accuracy: 0.0035
# Epoch 11/100
# 72/72 [==============================] - 7s 91ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0289 - val_accuracy: 0.0035
# Epoch 12/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0319 - val_accuracy: 0.0035
# Epoch 13/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0259 - val_accuracy: 0.0035
# Epoch 14/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0234 - val_accuracy: 0.0035
# Epoch 15/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0315 - val_accuracy: 0.0035
# Epoch 16/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0241 - val_accuracy: 0.0035
# Epoch 17/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0203 - val_accuracy: 0.0035
# Epoch 18/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0205 - val_accuracy: 0.0035
# Epoch 19/100
# 72/72 [==============================] - 7s 91ms/step - loss: 0.0056 - accuracy: 0.0000e+00 - val_loss: 0.0185 - val_accuracy: 0.0035
# Epoch 20/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0165 - val_accuracy: 0.0035
# Epoch 21/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0041 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0035
# Epoch 22/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0036 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0035
# Epoch 23/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0038 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0035
# Epoch 24/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 0.0195 - val_accuracy: 0.0035
# Epoch 25/100
# 72/72 [==============================] - 6s 89ms/step - loss: 0.0039 - accuracy: 0.0000e+00 - val_loss: 0.0150 - val_accuracy: 0.0035
# Epoch 26/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 0.0136 - val_accuracy: 0.0035
# Epoch 27/100
# 72/72 [==============================] - 7s 90ms/step - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 0.0187 - val_accuracy: 0.0035
# Epoch 28/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 0.0035
# Epoch 29/100
# 72/72 [==============================] - 7s 96ms/step - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0035
# Epoch 30/100
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0035
# Epoch 31/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0138 - val_accuracy: 0.0035
# Epoch 32/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0184 - val_accuracy: 0.0035
# Epoch 33/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 0.0194 - val_accuracy: 0.0035
# Epoch 34/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0370 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 72/72 [==============================] - 7s 93ms/step - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0162 - val_accuracy: 0.0035
# Epoch 36/100
# 72/72 [==============================] - 7s 95ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0385 - val_accuracy: 0.0035
# Epoch 37/100
# 72/72 [==============================] - 7s 95ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0506 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 72/72 [==============================] - 7s 95ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0333 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0193 - val_accuracy: 0.0035
# Epoch 40/100
# 72/72 [==============================] - 7s 94ms/step - loss: 0.0185 - accuracy: 0.0000e+00 - val_loss: 0.0236 - val_accuracy: 0.0035
# Epoch 1/100
# 72/72 [==============================] - 61s 722ms/step - loss: 0.0166 - accuracy: 0.0000e+00 - val_loss: 0.0322 - val_accuracy: 0.0035
# Epoch 2/100
# 72/72 [==============================] - 50s 692ms/step - loss: 0.0168 - accuracy: 0.0000e+00 - val_loss: 0.0534 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 72/72 [==============================] - 49s 682ms/step - loss: 0.0200 - accuracy: 0.0000e+00 - val_loss: 0.0537 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 72/72 [==============================] - 50s 688ms/step - loss: 0.0232 - accuracy: 0.0000e+00 - val_loss: 0.0663 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 72/72 [==============================] - 51s 707ms/step - loss: 0.0222 - accuracy: 0.0000e+00 - val_loss: 0.0637 - val_accuracy: 0.0035
# Epoch 6/100
# 72/72 [==============================] - 50s 690ms/step - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0394 - val_accuracy: 0.0035
# Epoch 7/100
# 72/72 [==============================] - 50s 695ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0189 - val_accuracy: 0.0035
# Epoch 8/100
# 72/72 [==============================] - 51s 707ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0142 - val_accuracy: 0.0035
# Epoch 9/100
# 72/72 [==============================] - 51s 705ms/step - loss: 0.0060 - accuracy: 0.0000e+00 - val_loss: 0.0162 - val_accuracy: 0.0035
# Epoch 10/100
# 72/72 [==============================] - 50s 688ms/step - loss: 0.0043 - accuracy: 0.0000e+00 - val_loss: 0.0134 - val_accuracy: 0.0035
# Epoch 11/100
# 72/72 [==============================] - 50s 689ms/step - loss: 0.0038 - accuracy: 0.0000e+00 - val_loss: 0.0093 - val_accuracy: 0.0035
# Epoch 12/100
# 72/72 [==============================] - 49s 686ms/step - loss: 0.0034 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0035
# Epoch 13/100
# 72/72 [==============================] - 49s 687ms/step - loss: 0.0030 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0035
# Epoch 14/100
# 72/72 [==============================] - 49s 688ms/step - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0035
# Epoch 15/100
# 72/72 [==============================] - 50s 691ms/step - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 0.0177 - val_accuracy: 0.0035
# Epoch 16/100
# 72/72 [==============================] - 50s 691ms/step - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0035
# Epoch 17/100
# 72/72 [==============================] - 50s 701ms/step - loss: 0.0029 - accuracy: 0.0000e+00 - val_loss: 0.0249 - val_accuracy: 0.0035
# Epoch 18/100
# 72/72 [==============================] - 51s 702ms/step - loss: 0.0029 - accuracy: 0.0000e+00 - val_loss: 0.0200 - val_accuracy: 0.0035
# Epoch 19/100
# 72/72 [==============================] - 50s 698ms/step - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0035
# Epoch 20/100
# 72/72 [==============================] - 50s 701ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0096 - val_accuracy: 0.0035
# Epoch 21/100
# 72/72 [==============================] - 50s 698ms/step - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 0.0035
# Epoch 22/100
# 72/72 [==============================] - 50s 695ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 0.0035
# Epoch 23/100
# 72/72 [==============================] - 50s 701ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0035
# Epoch 24/100
# 72/72 [==============================] - 51s 703ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0035
# Epoch 25/100
# 72/72 [==============================] - 50s 700ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0035
# Epoch 26/100
# 72/72 [==============================] - 51s 703ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0035
# Epoch 27/100
# 72/72 [==============================] - 51s 706ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0051 - val_accuracy: 0.0035
# Epoch 28/100
# 72/72 [==============================] - 51s 705ms/step - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 0.0035
# Epoch 29/100
# 72/72 [==============================] - 51s 715ms/step - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0097 - val_accuracy: 0.0035
# Epoch 30/100
# 72/72 [==============================] - 51s 707ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 0.0035
# Epoch 31/100
# 72/72 [==============================] - 51s 708ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0035
# Epoch 32/100
# 72/72 [==============================] - 50s 699ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0095 - val_accuracy: 0.0035
# Epoch 33/100
# 72/72 [==============================] - 50s 698ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 0.0035
# Epoch 34/100
# 72/72 [==============================] - 50s 697ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0035
# Epoch 35/100
# 72/72 [==============================] - 51s 703ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0156 - val_accuracy: 0.0035
# Epoch 36/100
# 72/72 [==============================] - 51s 702ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 0.0035
# Epoch 37/100
# 72/72 [==============================] - 51s 706ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 0.0035
# Epoch 1/100
# 72/72 [==============================] - 20s 215ms/step - loss: 0.0173 - accuracy: 0.0000e+00 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 72/72 [==============================] - 14s 195ms/step - loss: 0.0190 - accuracy: 0.0000e+00 - val_loss: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 72/72 [==============================] - 14s 197ms/step - loss: 0.0236 - accuracy: 0.0000e+00 - val_loss: 0.0795 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 72/72 [==============================] - 14s 197ms/step - loss: 0.0228 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 72/72 [==============================] - 14s 195ms/step - loss: 0.0189 - accuracy: 0.0000e+00 - val_loss: 0.0463 - val_accuracy: 0.0035
# Epoch 6/100
# 72/72 [==============================] - 14s 194ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0185 - val_accuracy: 0.0035
# Epoch 7/100
# 72/72 [==============================] - 14s 196ms/step - loss: 0.0052 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.
- val_accuracy: 0.0000e+00
# Epoch 6/100
# 72/72 [==============================] - 49s 683ms/step - loss: 0.0217 - accuracy: 0.0000e+00 - val_loss: 0.0413 - val_accuracy: 0.0035
# Epoch 7/100
# 72/72 [==============================] - 49s 681ms/step - loss: 0.0127 - accuracy: 0.0000e+00 - val_loss: 0.0181 - val_accuracy: 0.0035
# Epoch 8/100
# 72/72 [==============================] - 48s 670ms/step - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0138 - val_accuracy: 0.0035
# Epoch 9/100
# 72/72 [==============================] - 48s 668ms/step - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0035
# Epoch 10/100
# 72/72 [==============================] - 47s 657ms/step - loss: 0.0059 - accuracy: 0.0000e+00 - val_loss: 0.0099 - val_accuracy: 0.0035
# Epoch 11/100
# 72/72 [==============================] - 47s 659ms/step - loss: 0.0051 - accuracy: 0.0000e+00 - val_loss: 0.0091 - val_accuracy: 0.0035
# Epoch 12/100
# 72/72 [==============================] - 47s 647ms/step - loss: 0.0042 - accuracy: 0.0000e+00 - val_loss: 0.0154 - val_accuracy: 0.0035
# Epoch 13/100
# 72/72 [==============================] - 47s 656ms/step - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0035
# Epoch 14/100
# 72/72 [==============================] - 47s 653ms/step - loss: 0.0029 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0035
# Epoch 15/100
# 72/72 [==============================] - 47s 658ms/step - loss: 0.0029 - accuracy: 0.0000e+00 - val_loss: 0.0194 - val_accuracy: 0.0035
# Epoch 16/100
# 72/72 [==============================] - 47s 655ms/step - loss: 0.0052 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0035
# Epoch 17/100
# 72/72 [==============================] - 47s 650ms/step - loss: 0.0043 - accuracy: 0.0000e+00 - val_loss: 0.0186 - val_accuracy: 0.0035
# Epoch 18/100
# 72/72 [==============================] - 46s 643ms/step - loss: 0.0032 - accuracy: 0.0000e+00 - val_loss: 0.0099 - val_accuracy: 0.0035
# Epoch 19/100
# 72/72 [==============================] - 46s 643ms/step - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 0.0049 - val_accuracy: 0.0035
# Epoch 20/100
# 72/72 [==============================] - 47s 657ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0054 - val_accuracy: 0.0035
# Epoch 21/100
# 72/72 [==============================] - 47s 658ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 0.0035
# Epoch 22/100
# 72/72 [==============================] - 47s 656ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0035
# Epoch 23/100
# 72/72 [==============================] - 47s 654ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 0.0035
# Epoch 24/100
# 72/72 [==============================] - 47s 655ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 0.0035
# Epoch 25/100
# 72/72 [==============================] - 47s 649ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0035
# Epoch 26/100
# 72/72 [==============================] - 47s 651ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0071 - val_accuracy: 0.0035
# Epoch 27/100
# 72/72 [==============================] - 47s 655ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 0.0035
# Epoch 28/100
# 72/72 [==============================] - 48s 667ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0098 - val_accuracy: 0.0035
# Epoch 29/100
# 72/72 [==============================] - 48s 664ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0035

# %%
prediction_lstm = prediction(model_lstm)
prediction_bilstm = prediction(model_bilstm)
prediction_gru = prediction(model_gru)
prediction_bigru = prediction(model_bigru)

# %%
plot_future(prediction_lstm, 'LSTM', y_test)
plot_future(prediction_bilstm, 'Bidirectional LSTM', y_test)
plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_bigru, 'Bidirectional GRU', y_test)

# %%
def evaluate_prediction(actual, predictions, model_name):
    print(model_name + ':')
    print('r2_score: {:.4f}'.format(r2_score(actual, predictions)))
    print('Mean Absolute Error: {:.4f}'.format(mean_absolute_error(actual, predictions)))
    print('MSE: {:.4f}'.format(mean_squared_error(actual, predictions)))
    print('Root Mean Square Error: {:.4f}'.format(np.sqrt(mean_absolute_error(actual, predictions))))
    print('RMSLE: {:.4f}'.format(np.sqrt(mean_squared_error(actual, predictions))))
    print('')

def evaluate_prediction2(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    mae = np.abs(errors).mean()
    rmsle = np.sqrt(mse)
    rmse = np.sqrt(mae)

    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('MSE: {:.4f}'.format(mse))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('RMSLE: {:.4f}'.format(rmsle))
    print('')


evaluate_prediction(salesbymonth_test_final['sales'], salesbymonth_test_final['SeasonalARIMA'], 'ARIMA')
evaluate_prediction(result_xgboost['sales'], result_xgboost['Xgboost'], 'XGboost')

evaluate_prediction2(prediction_lstm, y_test, 'LSTM')
evaluate_prediction2(prediction_bilstm, y_test, 'Bidirectiona LSTM')
evaluate_prediction2(prediction_gru, y_test, 'GRU')
evaluate_prediction2(prediction_bigru, y_test, 'Bidirectiona GRU')
# Out:
# ARIMA:
# r2_score: 0.9915
# Mean Absolute Error: 12190.8863
# MSE: 240951261.2481
# Root Mean Square Error: 110.4123
# RMSLE: 15522.6048
#
# XGboost:
# r2_score: 0.9734
# Mean Absolute Error: 24963.1458
# MSE: 754579990.2773
# Root Mean Square Error: 157.9973
# RMSLE: 27469.6194
#
# LSTM:
# Mean Absolute Error: 30210.0427
# MSE: 949935139.6604
# Root Mean Square Error: 173.8104
# RMSLE: 30821.0178
#
# Bidirectiona LSTM:
# Mean Absolute Error: 30210.1070
# MSE: 949937803.9205
# Root Mean Square Error: 173.8105
# RMSLE: 30821.0610
#
# GRU:
# Mean Absolute Error: 30210.0889
# MSE: 949936805.9781
# Root Mean Square Error: 173.8105
# RMSLE: 30821.0449
#
# Bidirectiona GRU:
# Mean Absolute Error: 30210.1088
# MSE: 949937992.9951
# Root Mean Square Error: 173.8106
# RMSLE: 30821.0641

# %%
# testA_data_final['SeasonalARIMA'] = SARIMA_predict_day_1
# testA_data_final.plot()
# result_xgboost.plot()

plot_future(prediction_lstm, 'LSTM', y_test)
plot_future(prediction_bilstm, 'Bidirectional LSTM', y_test)
plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_bigru, 'Bidirectional GRU', y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-456d21bd83f4> in <module>()
#       3 # result_xgboost.plot()
#       4
# ----> 5 plot_future(prediction_lstm, 'LSTM', y_test)
#       6 plot_future(prediction_bilstm, 'Bidirectional LSTM', y_test)
#       7 plot_future(prediction_gru, 'GRU', y_test)
#
# <ipython-input-39-846f17526233> in plot_future(prediction, model_name, y_test)
#     117 # Plot test data vs prediction
#     118 def plot_future(prediction, model_name, y_test):
# --> 119     prediction = scaler.inverse_transform(prediction)
#     120     plt.figure(figsize=(18, 8))
#     121     range_future = len(prediction)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     527         )
#     528
# --> 529         X -= self.min_
#     530         X /= self.scale_
#     531         return X
#
# ValueError: non-broadcastable output operand with shape (5970,1) doesn't match the broadcast shape (5970,3)

# %%
from tensorflow.keras import load_model
model.save('mnist_mlp_model.h5')
